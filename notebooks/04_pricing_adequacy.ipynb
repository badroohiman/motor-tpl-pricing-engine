# %%
import pandas as pd
import numpy as np
import os

os.chdir(r"C:\Users\imanb\Documents\motor-tpl-pricing-engine")


freq = pd.read_parquet("data/staging/freq_staged.parquet")
sev  = pd.read_parquet("data/staging/sev_train.parquet")

# Crude baselines (not model outputs yet)
lambda_crude = freq["ClaimNb"].sum() / freq["Exposure"].sum()   # claims per year
mu_crude = sev["ClaimAmount"].mean()

lambda_crude, mu_crude, lambda_crude * mu_crude
